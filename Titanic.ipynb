# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_cleaned = titanic.dropna()

# %%
titanic_cleaned.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))

# Age distribution
plt.subplot(2, 2, 1)
plt.hist(titanic_cleaned['Age'], bins=30, edgecolor='k')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Fare distribution
plt.subplot(2, 2, 2)
plt.hist(titanic_cleaned['Fare'], bins=30, edgecolor='k')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Sex distribution
plt.subplot(1, 2, 1)
sex_counts = titanic_cleaned['Sex'].value_counts()
plt.bar(sex_counts.index, sex_counts.values, color='skyblue', edgecolor='k')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Frequency')

#Class distribution
plt.subplot(1,2,2)
class_counts = titanic_cleaned['Pclass'].value_counts()
plt.bar(class_counts.index.astype(str),class_counts.values,color='skyblue',edgecolor='k')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Survival rate by sex
plt.subplot(1, 2, 1)
titanic_cleaned.groupby('Sex')['Survived'].value_counts(normalize=True).unstack().plot(kind='bar', ax=plt.gca())
plt.title('Survival Rate by Sex')
plt.xlabel('Sex')
plt.ylabel('Proportion')

# Survival rate by class
plt.subplot(1, 2, 2)
titanic_cleaned.groupby('Pclass')['Survived'].value_counts(normalize=True).unstack().plot(kind='bar', ax=plt.gca())
plt.title('Survival Rate by Class')
plt.xlabel('Class')
plt.ylabel('Proportion')

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %%
#Age v/s Fair
plt.figure(figsize=(10,6))
plt.scatter(titanic_cleaned['Age'],titanic_cleaned['Fare'])
plt.title('Age vs Fair')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %%
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
titanic['Embarked'].fillna('Unknown', inplace=True)  # Fill missing values with 'Unknown'
titanic['Cabin'].fillna('Unknown', inplace=True)

# Convert categorical features to numerical values for correlation calculation
titanic['Sex'] = titanic['Sex'].map({'Male': 0, 'Female': 1})
titanic['Embarked'] = titanic['Embarked'].map({'S': 0, 'C': 1, 'Q': 2, 'Unknown': -1})  # Assign a numeric value to 'Unknown'

# Select only numeric columns for correlation calculation
numeric_columns = titanic.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_matrix = numeric_columns.corr()

# Plot the heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# C:\Users\nikhila\AppData\Local\Temp\ipykernel_27816\697275173.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   titanic['Embarked'].fillna('Unknown', inplace=True)  # Fill missing values with 'Unknown'
# C:\Users\nikhila\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
titanic_num = titanic.select_dtypes(include=['number'])
titanic_num.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
titanic_num.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
titanic_num = titanic_num.fillna(titanic_num.mean())
titanic_num.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
P = titanic_num.loc[titanic_num.Pclass == 1]
P_c = P.corr().round(2)
P_c
# Out:
#              PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00      0.16     NaN  0.00  -0.06  -0.03 -0.03
# Survived            0.16      1.00     NaN -0.21   0.16   0.06  0.19
# Pclass               NaN       NaN     NaN   NaN    NaN    NaN   NaN
# Age                 0.00     -0.21     NaN  1.00  -0.08  -0.19 -0.18
# SibSp              -0.06      0.16     NaN -0.08   1.00   0.26  0.26
# Parch              -0.03      0.06     NaN -0.19   0.26   1.00  0.38
# Fare               -0.03      0.19     NaN -0.18   0.26   0.38  1.00

# %%
plt.figure(figsize=(10,8))
plot = sns.heatmap(P.corr().round(2))
plt.plot

# %%
plt.figure(figsize=(12, 6))

sns.scatterplot(x='Age', y='Fare', hue='Survived', data=titanic_cleaned)
plt.title('Age vs Fare (Colored by Survival)')
plt.show()
